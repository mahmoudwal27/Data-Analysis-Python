# %% [markdown]
# # step 1: importing data

# %%
import pandas as pd
file = pd.read_excel('Ecommerce Data.xlsx')

# %% [markdown]
# # step 2: E.D.A.

# %%
file.head(2)
# Out:
#    OrderDate  OrderID Delivery Date  CustomerID  Customer Age Customer Gender  \
# 0 2020-05-31  5136486    2020-06-04   230569424            57               M
# 1 2020-05-31  5136457    2020-06-12   230568182            24               F
#
#   Location    Zone      Delivery Type   Product Category  \
# 0  Western  Zone 3            Express            Fashion
# 1  Western  Zone 3  Standard Delivery  Health and beauty
#
#                       SubCategory  \
# 0                  Girl's fashion
# 1  Medical supplies and Equipment
#
#                                              Product  Unit Price  \
# 0  Fashion Girl's Dress Kids Children Newborn Bab...         147
# 1  Blood Pressure Monitor Digital Wrist BP Pulse ...         131
#
#    Shipping Fee  Order Quantity  Sale Price    Status  \
# 0            10               2         196  Returned
# 1             4               7         183  Returned
#
#                               Reason  Rating
# 0       Onsite -Description mismatch       2
# 1  Product - Not fitting expectation       2

# %%
file.tail()
# Out:
#         OrderDate  OrderID Delivery Date  CustomerID  Customer Age  \
# 112995 2015-01-01  5023499    2015-01-20   230468761            48
# 112996 2015-01-01  5023506    2015-01-18   230466543            52
# 112997 2015-01-01  5023489    2015-01-18   230463891            36
# 112998 2015-01-01  5023465    2015-01-05   230462947            24
# 112999 2015-01-01  5023503    2015-01-15   230461323            51
#
#        Customer Gender       Location    Zone        Delivery Type  \
# 112995               M     North East  Zone 4  Shipped from Abroad
# 112996               M        Ashanti  Zone 3  Shipped from Abroad
# 112997               F        Western  Zone 3  Shipped from Abroad
# 112998               F        Ashanti  Zone 3              Express
# 112999               M  Greater Accra  Zone 1  Shipped from Abroad
#
#          Product Category                     SubCategory  \
# 112995    Home and Office             Kitchen and dinning
# 112996  Health and beauty        Beauty and personal care
# 112997  Health and beauty  Vitamins & Dietary Supplements
# 112998            Fashion                  Girl's fashion
# 112999            Fashion                   Men's fashion
#
#                                                   Product  Unit Price  \
# 112995  Heat Resistant Glass Storage Bowl - 15 Pieces ...          61
# 112996  L A Girl Pro Coverage HD Illuminating Liquid F...         106
# 112997      Aichun Beauty Eight Pack Essential Oil - 30ml          73
# 112998  Fashion Girls' Patent Leather Stitching Shoes ...         120
# 112999  100%Cotton 4 Piece Short Sleeve T-Shirts - Mul...          63
#
#         Shipping Fee  Order Quantity  Sale Price     Status Reason  Rating
# 112995            13               1         171  Delivered    NaN       5
# 112996             7               8         240  Delivered    NaN       4
# 112997            10               9         268  Delivered    NaN       4
# 112998             7               1         199  Delivered    NaN       2
# 112999            17               7         255  Delivered    NaN       2

# %%
file.shape
# Out:
# (113000, 19)

# %%
file.dtypes
# Out:
# OrderDate           datetime64[ns]
# OrderID                      int64
# Delivery Date       datetime64[ns]
# CustomerID                   int64
# Customer Age                 int64
# Customer Gender             object
# Location                    object
# Zone                        object
# Delivery Type               object
# Product Category            object
# SubCategory                 object
# Product                     object
# Unit Price                   int64
# Shipping Fee                 int64
# Order Quantity               int64
# Sale Price                   int64
# Status                      object
# Reason                      object
# Rating                       int64
# dtype: object

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113000 entries, 0 to 112999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   OrderDate         113000 non-null  datetime64[ns]
#  1   OrderID           113000 non-null  int64
#  2   Delivery Date     113000 non-null  datetime64[ns]
#  3   CustomerID        113000 non-null  int64
#  4   Customer Age      113000 non-null  int64
#  5   Customer Gender   112987 non-null  object
#  6   Location          112994 non-null  object
#  7   Zone              112997 non-null  object
#  8   Delivery Type     112990 non-null  object
#  9   Product Category  112994 non-null  object
#  10  SubCategory       112987 non-null  object
#  11  Product           113000 non-null  object
#  12  Unit Price        113000 non-null  int64
#  13  Shipping Fee      113000 non-null  int64
#  14  Order Quantity    113000 non-null  int64
#  15  Sale Price        113000 non-null  int64
#  16  Status            113000 non-null  object
#  17  Reason            29645 non-null   object
#  18  Rating            113000 non-null  int64
# dtypes: datetime64[ns](2), int64(8), object(9)
# memory usage: 16.4+ MB

# %%
file.describe()
# Out:
#                            OrderDate       OrderID  \
# count                         113000  1.130000e+05
# mean   2018-02-22 15:47:26.612389376  5.079973e+06
# min              2015-01-01 00:00:00  5.023455e+06
# 25%              2016-08-10 00:00:00  5.051716e+06
# 50%              2018-03-18 00:00:00  5.079970e+06
# 75%              2019-10-28 00:00:00  5.108233e+06
# max              2020-12-31 00:00:00  5.136490e+06
# std                              NaN  3.263155e+04
#
#                        Delivery Date    CustomerID   Customer Age  \
# count                         113000  1.130000e+05  113000.000000
# mean   2018-03-04 04:25:48.828318720  2.305156e+08      35.919673
# min              2015-01-03 00:00:00  2.304591e+08      17.000000
# 25%              2016-08-19 00:00:00  2.304874e+08      28.000000
# 50%              2018-03-27 00:00:00  2.305156e+08      35.000000
# 75%              2019-11-06 00:00:00  2.305439e+08      43.000000
# max              2021-01-20 00:00:00  2.305721e+08      87.000000
# std                              NaN  3.262048e+04      11.021883
#
#           Unit Price   Shipping Fee  Order Quantity     Sale Price  \
# count  113000.000000  113000.000000   113000.000000  113000.000000
# mean       99.953345      11.500434        5.334814     224.966566
# min        50.000000       3.000000        1.000000     150.000000
# 25%        75.000000       7.000000        3.000000     187.000000
# 50%       100.000000      12.000000        5.000000     225.000000
# 75%       125.000000      16.000000        8.000000     263.000000
# max       150.000000      20.000000       10.000000     300.000000
# std        29.195219       5.192076        2.924370      43.567035
#
#               Rating
# count  113000.000000
# mean        2.729929
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# std         1.355434

# %% [markdown]
# # step 3: data cleaning

# %% [markdown]
# #### step 3.1: deticting nulls

# %%
file.isnull().sum()
# Out:
# OrderDate               0
# OrderID                 0
# Delivery Date           0
# CustomerID              0
# Customer Age            0
# Customer Gender        13
# Location                6
# Zone                    3
# Delivery Type          10
# Product Category        6
# SubCategory            13
# Product                 0
# Unit Price              0
# Shipping Fee            0
# Order Quantity          0
# Sale Price              0
# Status                  0
# Reason              83355
# Rating                  0
# dtype: int64

# %% [markdown]
# #### step 3.2: deticting duplecits

# %%
file.duplicated().sum()
# Out:
# 0

# %%
duplicated=file[file.duplicated()]
duplicated
# Out:
# Empty DataFrame
# Columns: [OrderDate, OrderID, Delivery Date, CustomerID, Customer Age, Customer Gender, Location, Zone, Delivery Type, Product Category, SubCategory, Product, Unit Price, Shipping Fee, Order Quantity, Sale Price, Status, Reason, Rating]
# Index: []

# %% [markdown]
# #### step 3.3: nulls

# %%
file = file[file['Customer Gender'].notna()]
file = file[file['Location'].notna()]
file = file[file['Zone'].notna()]
file = file[file['Delivery Type'].notna()]
file = file[file['Product Category'].notna()]
file = file[file['SubCategory'].notna()]
file.isnull().sum()
# Out:
# OrderDate               0
# OrderID                 0
# Delivery Date           0
# CustomerID              0
# Customer Age            0
# Customer Gender         0
# Location                0
# Zone                    0
# Delivery Type           0
# Product Category        0
# SubCategory             0
# Product                 0
# Unit Price              0
# Shipping Fee            0
# Order Quantity          0
# Sale Price              0
# Status                  0
# Reason              83321
# Rating                  0
# dtype: int64

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112949 entries, 0 to 112999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   OrderDate         112949 non-null  datetime64[ns]
#  1   OrderID           112949 non-null  int64
#  2   Delivery Date     112949 non-null  datetime64[ns]
#  3   CustomerID        112949 non-null  int64
#  4   Customer Age      112949 non-null  int64
#  5   Customer Gender   112949 non-null  object
#  6   Location          112949 non-null  object
#  7   Zone              112949 non-null  object
#  8   Delivery Type     112949 non-null  object
#  9   Product Category  112949 non-null  object
#  10  SubCategory       112949 non-null  object
#  11  Product           112949 non-null  object
#  12  Unit Price        112949 non-null  int64
#  13  Shipping Fee      112949 non-null  int64
#  14  Order Quantity    112949 non-null  int64
#  15  Sale Price        112949 non-null  int64
#  16  Status            112949 non-null  object
#  17  Reason            29628 non-null   object
#  18  Rating            112949 non-null  int64
# dtypes: datetime64[ns](2), int64(8), object(9)
# memory usage: 17.2+ MB

# %% [markdown]
# #### step 3.4: Removing Duplicates

# %% [markdown]
# ##### No Duplicates

# %% [markdown]
# #### Step 4: Analysis

# %%
file['Product Category'].value_counts()
# Out:
# Product Category
# Health and beauty    35935
# Fashion              33376
# Phones and Tablet    17973
# Home and Office      15401
# Electronics          10264
# Name: count, dtype: int64

# %%
file['Product'].value_counts().head(5)
# Out:
# Product
# B5 HiFi 5.0 Ture Wireless Headsets Auto Pair Touch - Black                        2569
# Blood Pressure Monitor Digital Wrist BP Pulse Monitor Meter Heart Rate Measure    2569
# Leather Vintage Bracelet Watch - Black                                            2569
# Avon Soft Musk Eau de Toilette Spray - 50ml                                       2569
# Yazole Analog Quartz Wrist Watch - Black                                          2569
# Name: count, dtype: int64

# %%
len(file['Product'].unique())
# Out:
# 44

# %%
pivot_table = file.pivot_table(index='Product Category', values='Rating', aggfunc='mean').sort_values(by='Rating', ascending=False)
pivot_table
# Out:
#                      Rating
# Product Category
# Phones and Tablet  2.752851
# Fashion            2.728248
# Home and Office    2.727940
# Electronics        2.725058
# Health and beauty  2.722666

# %%
file['Rating_Cat']=pd.cut(file.Rating,bins=[0,1,2,3,4,5],labels=['VD','DS','N','S','VS'])

# %%
file['Rating_Cat']
# Out:
# 0         DS
# 1         DS
# 2          N
# 3         VD
# 4          N
#           ..
# 112995    VS
# 112996     S
# 112997     S
# 112998    DS
# 112999    DS
# Name: Rating_Cat, Length: 112949, dtype: category
# Categories (5, object): ['VD' < 'DS' < 'N' < 'S' < 'VS']

# %%
file[['Rating','Rating_Cat']]
# Out:
#         Rating Rating_Cat
# 0            2         DS
# 1            2         DS
# 2            3          N
# 3            1         VD
# 4            3          N
# ...        ...        ...
# 112995       5         VS
# 112996       4          S
# 112997       4          S
# 112998       2         DS
# 112999       2         DS
#
# [112949 rows x 2 columns]

# %%
pivot_table = file.pivot_table(index='Product Category', values='Rating', aggfunc='mean', margins=True).sort_values(by='Rating', ascending=False)
index_order = list(pivot_table.index)
index_order.remove('All')
index_order.append('All')
pivot_table = pivot_table.reindex(index_order)
pivot_table
# Out:
#                      Rating
# Product Category
# Phones and Tablet  2.752851
# Fashion            2.728248
# Home and Office    2.727940
# Electronics        2.725058
# Health and beauty  2.722666
# All                2.730055

# %% [markdown]
# ### group by

# %%
total_sales_by_location = file.groupby('Location')['Sale Price'].sum().sort_values(ascending=False).head(10)
total_sales_by_location
# Out:
# Location
# Greater Accra    6400792
# Ashanti          5350594
# Western          4007200
# Weija            3069080
# Upper West       1262721
# Volta            1121410
# Upper East        764909
# Prampram          535484
# Savannah          523386
# Oyarifa           327831
# Name: Sale Price, dtype: int64

# %%
import plotly.express as px

pivot_table = file.pivot_table(index='Product Category', values='Order Quantity', aggfunc='count').sort_values(by='Order Quantity', ascending=False)

fig = px.pie(
    values=pivot_table['Order Quantity'],
    names=pivot_table.index,
    title='Order Quantity by Product Category'
)
fig.update_layout(title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="14c7b75f-81a0-44ae-a397-458f2b120eba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14c7b75f-81a0-44ae-a397-458f2b120eba")) {                    Plotly.newPlot(                        "14c7b75f-81a0-44ae-a397-458f2b120eba",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Health and beauty","Fashion","Phones and Tablet","Home and Office","Electronics"],"legendgroup":"","name":"","showlegend":true,"values":[35935,33376,17973,15401,10264],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterp ...

# %%
pivot_table = file.pivot_table(index='Product Category', values='Order Quantity', aggfunc='count').sort_values(by='Order Quantity', ascending=False)
pivot_table
# Out:
#                    Order Quantity
# Product Category
# Health and beauty           35935
# Fashion                     33376
# Phones and Tablet           17973
# Home and Office             15401
# Electronics                 10264
